# %% [markdown]
# ## Import / Config

# %%
import pandas as pd
from sqlalchemy import create_engine, text
import cred_pg as c
import folium

# %%
def lat_lng_from_sql(sql, engine):
    with engine.connect() as con:
        lat_lng_df = pd.read_sql_query(text(sql), con)
    return lat_lng_df.iat[0,0], lat_lng_df.iat[0,1]

def geojson_from_sql(sql, engine):
    with engine.connect() as con:
        geojson_df = pd.read_sql_query(text(sql), con)
    return geojson_df.iat[0,0]

# %% [markdown]
# ## Engine

# %%
engine = create_engine(
    f'postgresql://{c.pg_userid}:{c.pg_password}@{c.pg_host}/{c.pg_db}', 
    connect_args = {'options': '-c search_path=$user,ugeobln,umisc,umobility,usozmed,public', 'keepalives_idle': 120},
    pool_size=1, 
    max_overflow=0,
    execution_options={ 'isolation_level': 'AUTOCOMMIT' }
)

# %%
# engine.dispose()

# %% [markdown]
# ## HTW

# %%
sql = """
select ST_Y(ST_Centroid(geometry)) as lat, ST_X(ST_Centroid(geometry)) as lng
from gis_osm_pois_a_free_1 
where osm_id ='41361350'; 
"""

lat, lng = lat_lng_from_sql(sql, engine)
print(f"{lat}, {lng}")
m = folium.Map(location=[lat, lng], zoom_start=16)
folium.Marker(
    location=[lat, lng],
    tooltip="HTW"
).add_to(m)

sql = """
select ST_AsGeoJSON(geometry)
from gis_osm_pois_a_free_1 
where osm_id ='41361350'; 
"""
geojson = geojson_from_sql(sql, engine)
folium.GeoJson(geojson).add_to(m)
m
# Out:
# 52.45625748689952, 13.525910838604682
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fd76375b4568a83179fd3a2ac372409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fd76375b4568a83179fd3a2ac372409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fd76375b4568a83179fd3a2ac372409 = L.map(
#                 &quot;map_1fd76375b4568a83179fd3a2ac372409&quot;,
#                 {
#                     center: [52.45625748689952, 13.525910838604682],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dafc562db5f9bc49c32094ff389e3c03 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fd76375b4568a83179fd3a2ac372409);
#
#
#             var marker_3c2e22a36a4e40522d5962c4be605352 = L.marker(
#                 [52.45625748689952, 13.525910838604682],
#                 {}
#             ).addTo(map_1fd76375b4568a83179fd3a2ac372409);
#
#
#             marker_3c2e22a36a4e40522d5962c4be605352.bindTooltip(
#                 `&lt;div&gt;
#                      HTW
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_b563c970245dfbe4887e22830e883a64_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b563c970245dfbe4887e22830e883a64 = L.geoJson(null, {
#                 onEachFeature: geo_json_b563c970245dfbe4887e22830e883a64_onEachFeature,
#
#         });
#
#         function geo_json_b563c970245dfbe4887e22830e883a64_add (data) {
#             geo_json_b563c970245dfbe4887e22830e883a64
#                 .addData(data)
#                 .addTo(map_1fd76375b4568a83179fd3a2ac372409);
#         }
#             geo_json_b563c970245dfbe4887e22830e883a64_add({&quot;coordinates&quot;: [[[13.5233918, 52.4557753], [13.5238813, 52.4561499], [13.5251446, 52.4555986], [13.5252735, 52.4557068], [13.5257798, 52.4561412], [13.5255179, 52.4562546], [13.525568, 52.4562976], [13.5251867, 52.4564621], [13.5253453, 52.4566033], [13.5252641, 52.456638], [13.5248649, 52.4568085], [13.5250089, 52.4569337], [13.5245304, 52.4571287], [13.5259032, 52.4582858], [13.5262133, 52.4581505], [13.5264591, 52.4583632], [13.5265028, 52.4583285], [13.5265543, 52.4582884], [13.5269448, 52.4579954], [13.5272347, 52.4577801], [13.5275366, 52.457564], [13.5276147, 52.4575009], [13.5275799, 52.4574705], [13.5267701, 52.4567394], [13.527444, 52.4564425], [13.5268478, 52.4559167], [13.5275359, 52.4556222], [13.5275411, 52.4555348], [13.5271147, 52.4551694], [13.5268225, 52.4549189], [13.5268627, 52.4548645], [13.5268443, 52.4548492], [13.5262362, 52.4543407], [13.5261567, 52.4542921], [13.5252929, 52.4545714], [13.5235224, 52.4556701], [13.5233918, 52.4557753]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Bezirke

# %%
m = folium.Map(location=[52.5170365, 13.3888599], zoom_start=10)

sql = """
select name as bname, ST_AsGeoJSON(shape) as geojson
from bezirk; 
"""
with engine.connect() as con:
    pdf = pd.read_sql_query(text(sql), con)

for b in pdf.apply(lambda r: folium.GeoJson(r.geojson), axis=1):
    b.add_to(m)

sql = """
select 
  name as bname, 
  ST_Y(ST_Centroid(shape)) as clat, 
  ST_X(ST_Centroid(shape)) as clng
from bezirk;
"""
with engine.connect() as con:
    pdf = pd.read_sql_query(text(sql), con)

def cmarker(r):
    loc = [r.clat, r.clng]
    html = f'<font color="green">{r.bname}</font>'
    divicon = folium.DivIcon(html=html)
    return folium.Marker(location=loc, icon=divicon)

for bc in pdf.apply(lambda r: cmarker(r), axis=1):
    bc.add_to(m)

sql = """
select ST_AsGeoJSON(ST_Extent(shape)) as bbox
from bezirk; 
"""
bb_berlin = geojson_from_sql(sql, engine)
folium.GeoJson(bb_berlin).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d56a350c5738995ab57104eab883ae1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d56a350c5738995ab57104eab883ae1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d56a350c5738995ab57104eab883ae1 = L.map(
#                 &quot;map_9d56a350c5738995ab57104eab883ae1&quot;,
#                 {
#                     center: [52.5170365, 13.3888599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85ab49a6565f2b9acfe27a95e9134eb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d56a350c5738995ab57104eab883ae1);
#
#
#
#         function geo_json_f6479102a03ca2e820a29cc6198e39bf_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f6479102a03ca2e820a29cc6198e39bf = L.geoJson(null, {
#                 onEachFeature: geo_json_f6479102a03ca2e820a29cc6198e39bf_onEachFeature,
#
#         });
#
#         function geo_json_f6479102a03ca2e820a29cc6198e39bf_add (data) {
#             geo_json_f6479102a03ca2e820a29cc6198e39bf
#                 .addData(data)
#                 .addTo(map_9d56a350c5738995ab57104eab883ae1);
#         }
#             geo_json_f6479102a03ca2e820a29cc6198e39bf_add({&quot;coordinates&quot;: [[[13.320744328, 52.626599064], [13.320450024, 52.62661432], [13.320156209, 52.626629556], [13.319861608, 52.626644835], [13.319593628, 52.626658718], [13.319363587, 52.626698899], [13.319271319, 52.626714583], [13.319136649, 52.626737909], [13.319076929, 52.626748265], [13.319052551, 52.626752487], [13.318885692, 52.626781389], [13.318881134, 52.626782736], [13.318360954, 52.626934862], [13.31831405, 52.626948527], [13.318291711, 52.626955034], [13.318159776, 52.626993711], [13.318049255, 52.627021443], [13.318037351, 52.627024421], [13.317772404, 52.62709086], [13.317677445, 52.62711501], [13.317611418, 52.627131865], [13.317450003, 52.627172873], [13.317346749, 52.627199117], [13.31728532, 52.627207379], [13.31700348, 52.627248096], [13.316935923, 52.627257799], [13.316721564, 52.627288874], [13.316673171, 52.627295865], [13.316640556, 52.627300616], [13.316476198, 52.627324336], [13.316441662, 52.627331785], [13.316336952, 52.627354383], [13.316164451, 52.627391608], [13.316057817, 52.627414629], [13.315951439, 52.627437572], [13.315896772, 52.627448645], [13.315714589, 52.627485552], [13.31570351, 52.627487795], [13.315389985, 52.627551299], [13.315370923, 52.627555155], [13.315270018, 52.627575595], [13.315149217, 52.627600068], [13.315076621, 52.62761477], [13.315000645, 52.627630133], [13.314987183, 52.627632882], [13.314928571, 52.627652395], [13.314798177, 52.627695809], [13.314724029, 52.627720496], [13.314497155, 52.627796029], [13.31447252, 52.627804229], [13.314454379, 52.627810273], [13.314174221, 52.627903542], [13.313857191, 52.627988481], [13.313690276, 52.628033245], [13.313513015, 52.628080766], [13.313378068, 52.628116885], [13.313347026, 52.628122197], [13.313100083, 52.628164679], [13.313011658, 52.628179809], [13.31298652, 52.628184145], [13.312689184, 52.628191085], [13.312434985, 52.628197067], [13.312334685, 52.628199405], [13.312192688, 52.628189415], [13.312002124, 52.628175965], [13.31197202, 52.628173819], [13.311950419, 52.628172243], [13.31185192, 52.62816504], [13.311350228, 52.628128353], [13.31133283, 52.628127755], [13.311235954, 52.62812444], [13.311112797, 52.62812023], [13.311032772, 52.628117497], [13.311015212, 52.628116896], [13.311004496, 52.628115817], [13.310630328, 52.628080856], [13.310564033, 52.628074642], [13.310471677, 52.628067516], [13.310367683, 52.628059488], [13.310233518, 52.628049149], [13.310174031, 52.628044533], [13.309994688, 52.628032075], [13.309754985, 52.628016616], [13.30943109, 52.627995738], [13.309276084, 52.627986359], [13.30873588, 52.627962176], [13.308697944, 52.627960456], [13.308506751, 52.627951855], [13.308398335, 52.627934761], [13.308189297, 52.627901935], [13.308125425, 52.627891879], [13.307898108, 52.627856039], [13.30789235, 52.627855129], [13.307593931, 52.627808222], [13.307553866, 52.627801904], [13.307449476, 52.627785442], [13.307404374, 52.627778324], [13.307382548, 52.627774946], [13.307215856, 52.627748702], [13.307210687, 52.627748241], [13.306969966, 52.627727817], [13.306723564, 52.627706016], [13.306672142, 52.627701495], [13.306522916, 52.627688258], [13.306406099, 52.627677921], [13.306379476, 52.627675544], [13.306330042, 52.627671187], [13.306296704, 52.627668246], [13.306188665, 52.627658637], [13.306068164, 52.627650745], [13.306009595, 52.62764686], [13.305864982, 52.627637356], [13.305828874, 52.627634978], [13.305679296, 52.627625098], [13.305596364, 52.627616224], [13.305

# %% [markdown]
# ## Haltestellen

# %%
m = folium.Map(location=[52.5170365, 13.3888599], zoom_start=13)
sql = """
select ST_AsGeoJSON(
    ST_Transform((st_dump(ST_VoronoiPolygons(
        st_collect(h.posp)))).geom, 4326)
    ) as geojson
from haltestelle h
"""
with engine.connect() as con:
    pdf = pd.read_sql_query(text(sql), con)

for v in pdf.apply(lambda r: folium.GeoJson(r.geojson), axis=1):
    v.add_to(m)

sql = """
select bez, lat, lng
from haltestelle;
"""
with engine.connect() as con:
    pdf = pd.read_sql_query(text(sql), con)

def hcircle(r):
    loc = [r.lat, r.lng]
    return folium.Circle(
        location=loc, radius=20, 
        fill=True, fill_color="blue", 
        tooltip=r.bez
    )

for h in pdf.apply(lambda r: hcircle(r), axis=1):
    h.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e443e14efd27f431e2ed1efc4ceb56e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e443e14efd27f431e2ed1efc4ceb56e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e443e14efd27f431e2ed1efc4ceb56e2 = L.map(
#                 &quot;map_e443e14efd27f431e2ed1efc4ceb56e2&quot;,
#                 {
#                     center: [52.5170365, 13.3888599],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2415381085bd489c5cceec77dc10f096 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e443e14efd27f431e2ed1efc4ceb56e2);
#
#
#
#         function geo_json_407f9f3f30f29a503d685d81c1a76873_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_407f9f3f30f29a503d685d81c1a76873 = L.geoJson(null, {
#                 onEachFeature: geo_json_407f9f3f30f29a503d685d81c1a76873_onEachFeature,
#
#         });
#
#         function geo_json_407f9f3f30f29a503d685d81c1a76873_add (data) {
#             geo_json_407f9f3f30f29a503d685d81c1a76873
#                 .addData(data)
#                 .addTo(map_e443e14efd27f431e2ed1efc4ceb56e2);
#         }
#             geo_json_407f9f3f30f29a503d685d81c1a76873_add({&quot;coordinates&quot;: [[[12.770560724, 52.832904609], [12.939931902, 52.736403296], [13.209836894, 52.532532817], [13.213340645, 52.519125382], [13.204582934, 52.505712238], [13.182035399, 52.483033643], [12.763234644, 52.414255296], [12.770560724, 52.832904609]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#
#         function geo_json_4d14fff9232b5d46a968360f3ad16446_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4d14fff9232b5d46a968360f3ad16446 = L.geoJson(null, {
#                 onEachFeature: geo_json_4d14fff9232b5d46a968360f3ad16446_onEachFeature,
#
#         });
#
#         function geo_json_4d14fff9232b5d46a968360f3ad16446_add (data) {
#             geo_json_4d14fff9232b5d46a968360f3ad16446
#                 .addData(data)
#                 .addTo(map_e443e14efd27f431e2ed1efc4ceb56e2);
#         }
#             geo_json_4d14fff9232b5d46a968360f3ad16446_add({&quot;coordinates&quot;: [[[12.763234644, 52.414255296], [13.182035399, 52.483033643], [13.193866033, 52.482438686], [13.26215189, 52.436246291], [13.280029373, 52.411800441], [13.309398877, 52.357643892], [13.300723253, 52.19602427], [13.292181672, 52.155984905], [13.29139136, 52.153136139], [12.758836101, 52.15776851], [12.763234644, 52.414255296]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#
#         function geo_json_e29fdab44720140314a47f3c633fb8cd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e29fdab44720140314a47f3c633fb8cd = L.geoJson(null, {
#                 onEachFeature: geo_json_e29fdab44720140314a47f3c633fb8cd_onEachFeature,
#
#         });
#
#         function geo_json_e29fdab44720140314a47f3c633fb8cd_add (data) {
#             geo_json_e29fdab44720140314a47f3c633fb8cd
#                 .addData(data)
#                 .addTo(map_e443e14efd27f431e2ed1efc4ceb56e2);
#         }
#             geo_json_e29fdab44720140314a47f3c633fb8cd_add({&quot;coordinates&quot;: [[[12.771154227, 52.866381328], [13.214156882, 52.862674687], [13.306024584, 52.603319053], [13.304930189, 52.591481643], [13.239569144, 52.571125087], [13.221357924, 52.577957534], [12.939931902, 52.736403296], [12.770560724, 52.832904609], [12.771154227, 52.866381328]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#
#         function geo_json_a4faf492ba8e103fdd804a13da2405dc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a4faf492ba8e103fdd804a13da2405dc = L.geoJson(null, {
#                 onEachFeature: geo_json_a4faf492ba8e103fdd804a13da2405dc_onEachFeature,
#
#         });
#
#         function geo_json_a4faf492ba8e103fdd804a13da2405dc_add (data) {
#             geo_json_a4faf492ba8e103fdd804a13da2405dc
#                 .addData(data)
#                 .addTo(map_e443e14efd27f431e2ed1efc4ceb56e2);
#         }
#             geo_json_a4faf492ba8e103fdd804a13da2405dc_add({&quot;coordinates&quot;: [[[13.209836894, 52.532532817], [12.939931902, 52.736403296], [13.221357924, 52.577957534], [13.22045793, 52.558693169], [13.209836894, 52.532532817]]], &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#
#         function geo_json_e1cd019f01f5e81b68a01bed7a022184_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e1cd019f01f5e81b68a01bed7a022184 = L.geoJson(null, {
#                 onEachFeature: geo_json_e1cd019f01f5e81b68a01bed7a022
